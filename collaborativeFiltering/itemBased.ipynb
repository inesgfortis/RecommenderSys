# %%
import os
os.chdir('../movies')
from movieLens import MovieLens

# %%
ml = MovieLens()

# %% [markdown]
# # Algorithm

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, KNNWithMeans, accuracy
from surprise.model_selection import train_test_split, GridSearchCV
import heapq
from collections import defaultdict
from operator import itemgetter

# %%
# Load the ratings dataset
ratings = ml.ratings.copy()

# Method from the Surprise library to load the DataFrame 
# Define the Reader object to parse the dataframe
reader = Reader(rating_scale=(ratings['rating'].min(), ratings['rating'].max()))

# Load the dataframe as a ratings dataset
ratingsDataset = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# Build the full trainset
trainSet, testSet = train_test_split(ratingsDataset, test_size=0.2, random_state=42)
antitest = trainSet.build_anti_testset()

# %% [markdown]
# ## Item user rating matrix

# %% [markdown]
# Matriz en la que encontramos los ratings por película para cada uno de los usuarios existentes. Una columna para las películas y una fila en la que se encuentran todos los usuarios disponibles. El valor de la celda corresponde con el rating otorgado a cada una de las películas por el usuario correspondiente

# %%
# Cosine similarity function
sim_options = {'name': 'cosine',   # alternative: pearson
               'user_based': False, # compute  similarities between films
               'min_support':5      # minimum number of common items between users
               }

model = KNNWithMeans(sim_options=sim_options)
model.fit(trainSet)
simsMatrix = model.compute_similarities()
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ## Look up similar items

# %% [markdown]
# Buscamos las k películas que el usuario de referencia haya valorado mejor

# %%
def getNeighbors(referenceUser,k,trainSet):
     
    referenceUserInnerID = trainSet.to_inner_uid(referenceUser) 

    # Get top N items rated
    # Sort the elements in decreasing order by score and select top N
    referenceUserRatings = trainSet.ur[referenceUserInnerID]
    #print(referenceUserRatings)
    kNeighbors = heapq.nlargest(k, referenceUserRatings, key=lambda t: t[1])
    
    return kNeighbors

# %%
# Reference user = user to recommend to
referenceUser = 1 

# Set the number of desired similar users
k = 10

# %%
# Get neighbours
kNeighbors = getNeighbors(referenceUser,10,trainSet)
kNeighbors
# Out:
# [(587, 5.0),
#  (18, 5.0),
#  (126, 5.0),
#  (85, 5.0),
#  (1075, 5.0),
#  (1198, 5.0),
#  (589, 5.0),
#  (991, 5.0),
#  (1579, 5.0),
#  (95, 5.0)]

# %% [markdown]
# De esta forma se seleccionan las k primeras películas con mayor puntuación, en este caso se seleccionan las 10 primeras, pero, no deberíamos seleccionar un número variable de k de tal forma que se seleccionen todas aquellas que tengan un rating máximo (5)?

# %% [markdown]
# ## Candidate generation and scoring

# %% [markdown]
# Selecionamos las películas que podríamos recomendar en primera instancia. Para ello normalizamos los ratings y multiplicamos por el coeficiente de semejanza entre las películas

# %%
# Get similar items to stuff we liked (weighted by rating)
candidates = defaultdict(float)
for itemID, rating in kNeighbors:
    similarityRow = simsMatrix[itemID]
    for innerID, score in enumerate(similarityRow):
#         print(score)
#         print(rating)
        candidates[innerID] += score*(rating/5.0)

# Sort the candidates by score
candidates = sorted(candidates.items(), key=itemgetter(1), reverse=True)
#candidates

# %% [markdown]
# El score corresponde con la medida cosine similarity entre las películas calculada en la matriz de similaridad, mientras que rating corresponde con la valoración del usuario

# %% [markdown]
# ## Candidate filtering and recommendations

# %% [markdown]
# Filtramos aquellas recomendaciones con un score pequeño y que ya haya visto el usuario. Para ello utilizamos un set porque únicamente nos interesa saber los items que el reference user ya ha visto, plus es un objeto eficiente para datasets largos

# %%
def filterRec(referenceUser,trainSet,k,candidates):
    
    # Get top N similar users to our reference user
    referenceUserInnerID = trainSet.to_inner_uid(referenceUser)
    
    # Build a set of movies the user has already seen
    watched = set(trainSet.ur[referenceUserInnerID])
    
    # Initialize a list to store the recommendations
    recommendations = []

    # Get top-rated items from similar users:
    pos = 0
    for itemID, ratingSum in candidates:
        if not itemID in watched:
            movieID = trainSet.to_raw_iid(itemID)
            recommendation = ml.getMovieName(int(movieID)), ratingSum
            recommendations.append(recommendation)
            pos += 1
            if (pos >= k):
                break            

    rec_movies = [rec[0] for rec in recommendations]
    return rec_movies

# %% [markdown]
# ratingSum represents the total similarity of the reference user to all other users who rated that item

# %%
# Results for the first approach
rec_movies = filterRec(referenceUser,trainSet,k,candidates)
rec_movies
# Out:
# ['Star Wars: Episode V - The Empire Strikes Back',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Apocalypse Now',
#  'Chinatown',
#  'Toy Story',
#  'Fargo',
#  'Blade Runner',
#  'Citizen Kane',
#  'L.A. Confidential',
#  'Psycho']

# %% [markdown]
# # Metrics

# %%
import os
os.chdir('../metrics')
from metrics import evaluationMetrics
em = evaluationMetrics()

# %%
# Get test and antitest predictions
predtest = model.test(testSet)
predantitest = model.test(antitest)

# Get top N recommended movies for each user based on estimated ratings
top_10 = em.getTopN(predantitest,minimumRating = 3.5)

# %%
predtest
# Out:
# [Prediction(uid=140, iid=6765, r_ui=3.5, est=3.62814377955575, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid=603, iid=290, r_ui=4.0, est=3.9473255245212706, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid=438, iid=5055, r_ui=4.0, est=3.094520855306915, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid=433, iid=164179, r_ui=5.0, est=3.367120664378315, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid=474, iid=5114, r_ui=4.0, est=3.503229285466356, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=304, iid=1035, r_ui=4.0, est=4.448442530397763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=298, iid=4974, r_ui=1.0, est=2.1862738423932875, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid=131, iid=293, r_ui=4.0, est=3.4948668029190832, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=288, iid=5784, r_ui=2.5, est=2.9572629532985015, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid=448, iid=97225, r_ui=2.5, est=3.2574516436786385, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid=284, iid=585, r_ui=4.0, est=3.185352169566769, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=331, iid=48394, r_ui=5.0, est=3.8246610764511515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=325, iid=2204, r_ui=3.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=504, iid=2797, r_ui=3.5, est=4.012713794904111, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=286, iid=509, r_ui=3.5, est=3.687806850562349, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=232, iid=8807, r_ui=4.0, est=3.5258557526516707, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=448, iid=72378, r_ui=1.5, est=2.072026350939469, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=6, iid=112, r_ui=4.0, est=3.7791868099138024, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=54, iid=339, r_ui=3.0, est=2.7260568333879953, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid=264, iid=3623, r_ui=2.0, est=2.5870093880164484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=45, iid=356, r_ui=5.0, est=4.646192334621039, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=448, iid=98175, r_ui=1.5, est=3.503229285466356, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=525, iid=46578, r_ui=4.5, est=3.6988043570834517, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=577, iid=1210, r_ui=4.0, est=4.103380919119675, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=226, iid=5541, r_ui=3.5, est=3.3506698036204834, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=597, iid=1079, r_ui=5.0, est=4.3969932548052055, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=20, iid=5816, r_ui=4.5, est=3.98234759426458, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=386, iid=608, r_ui=4.0, est=3.6395643385603167, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=405, iid=110, r_ui=4.0, est=4.162564728680086, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=136, iid=432, r_ui=3.0, est=2.548529151128532, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=275, iid=858, r_ui=5.0, est=4.607002104382709, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=160, iid=1972, r_ui=1.0, est=2.3333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=580, iid=5319, r_ui=3.5, est=3.923803826214315, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid=238, iid=1961, r_ui=2.0, est=3.802670087407118, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid=448, iid=4022, r_ui=4.0, est=3.219788895522018, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=64, iid=4105, r_ui=3.0, est=4.016892509888017, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=382, iid=45720, r_ui=4.5, est=4.043662888065651, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=555, iid=1971, r_ui=3.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=298, iid=32587, r_ui=3.5, est=2.7524003187412465, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %% [markdown]
# ## Métricas de precisión: RMSE y MAE

# %%
# RMSE
rmse = accuracy.rmse(predtest)

# MAE
mae = accuracy.mae(predtest)
# Out:
# RMSE: 0.9172
# MAE:  0.6978

# %% [markdown]
# ## Métricas de relevancia: Precision, Recall y NDCG

# %%
# Precision
precisions = em.getPrecision(predtest, k=10, threshold=3.5)

# Mean Average Precision
mapModel = np.mean(list(precisions.values()))

# Recall
recalls = em.getRecall(predtest, k=10, threshold=3.5)

# Mean Average Recall
marModel = np.mean(list(recalls.values()))

# Normalized discounted cummulative gain (NDCG)
ndcgs, mean_ndcg = em.getNDCG(predtest,10)

# %% [markdown]
# ## Otras métricas de interés: Coverage, User Coverage y Novelty

# %%
# Coverage
coverage = em.getCoverage(top_10,trainSet.n_items,trainSet.all_users())

# User coverage
user_coverage = em.getUserCoverage(top_10, trainSet.n_users,4)

# Novelty
novelty = em.getNovelty(top_10,trainSet)

# %% [markdown]
# Por último creamos un dataframe con todas las métricas de evaluación asociadas al modelo

# %%
cols = ["Model","RMSE","MAE","MAP","MAR","Mean_NDCG","Coverage","User_Coverage","Novelty"]
metrics_data = []

# Append the results to the list of dictionaries
metrics_data.append({"Model": "item-based", "RMSE": rmse, "MAE": mae, "MAP": mapModel, "MAR": marModel,
                     "Mean_NDCG": mean_ndcg, "Coverage": coverage, "User_Coverage": user_coverage,
                     "Novelty": novelty})

# Convert the list of dictionaries into a DataFrame
metrics_df = pd.DataFrame(metrics_data, columns=cols)
metrics_df
# Out:
#         Model      RMSE       MAE       MAP       MAR  Mean_NDCG  Coverage  \
# 0  item-based  0.917171  0.697839  0.743048  0.447952   0.951819  0.020721
#
#    User_Coverage      Novelty
# 0            1.0  5853.927869

# %% [markdown]
# * **Coverage**: las recomendaciones son poco variadas, en torno a un 2%.
# * **User Coverage**: aquí vemos como el modelo encuentra para todos sus usuarios al menos una recomendación por encima de 4 en su predicción
# * **Novelty**: recomendaciones que han sido pocas veces puntuadas; ranking promedio en torno a la película 5853 más popular (de 8000 posibles)

# %% [markdown]
# Finalmente añadimos los resultados al dataframe con la métricas de todos los modelos

# %%
# Add the results to the dataframe with the metrics of all models.
em.addToMetricsDataframe(metrics_df)

# %% [markdown]
# Y guardamos las recomendaciones resultantes del modelo para los dos usuarios de referencias (userId = 1 y userId = 4)

# %%
# Obtain the desired recomendations
recs_user1 = [ml.movieID_to_name[movie_id] for movie_id, _ in top_10[1]]
recs_user4 = [ml.movieID_to_name[movie_id] for movie_id, _ in top_10[4]]

em.addUserRecommendations("rec_user1.xlsx", "item-based", recs_user1)
em.addUserRecommendations("rec_user4.xlsx", "item-based", recs_user4)
